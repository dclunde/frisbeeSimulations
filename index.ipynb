# %%
# %matplotlib notebook

# %%
from frisbee_current import Simulation

# %%
Simulation()
# Out:
# Frisbee hit the ground, ending simulation
# <img src="data:image/png;base64,...">

# %%
# %run frisbee_sliders.py
# Out:
# ERROR: File `u'frisbee_sliders.py'` not found.
