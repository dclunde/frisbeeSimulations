# %% [markdown]
# # Frisbee Simulations
# ### Senior project by Dominic Lunde
# ##### Physics BS at California Lutheran University

# %% [markdown]
# Run the cell below this in order to view simulation

# %%
# %matplotlib notebook

# %%
from frisbee_current import Simulation

# %%
Simulation()
# Out:
# 0 - Forehand
# 1 - Backhand
# 2 - Bounce
# 3 - High Drop
# 4 - Backhand left
# Choose type :4
# Beginning Frisbee Simulation
# Frisbee hit the ground, ending simulation
# Finished simulation in 0.107979 seconds
# <img src="data:image/png;base64,...">
# Finished everything  in 0.702637 seconds

# %% [markdown]
# Run the cell above to re-run simulation
